# %% [markdown]
# # **Analysis**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.get_dataset_names()
print(data)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
data = sns.load_dataset('titanic')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
data = data.set_index('survived')
data.head()
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S  Third    man
# 1              1  female  38.0      1      0  71.2833        C  First  woman
# 1              3  female  26.0      0      0   7.9250        S  Third  woman
# 1              1  female  35.0      1      0  53.1000        S  First  woman
# 0              3    male  35.0      0      0   8.0500        S  Third    man
#
#           adult_male deck  embark_town alive  alone
# survived
# 0               True  NaN  Southampton    no  False
# 1              False    C    Cherbourg   yes  False
# 1              False  NaN  Southampton   yes   True
# 1              False    C  Southampton   yes  False
# 0               True  NaN  Southampton    no   True

# %%
data.shape # the first element indicate no of rows and second indicate no of columns
# Out:
# (891, 14)

# %%
data.columns
# Out:
# Index(['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class',
#        'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 0
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pclass       891 non-null    int64
#  1   sex          891 non-null    object
#  2   age          714 non-null    float64
#  3   sibsp        891 non-null    int64
#  4   parch        891 non-null    int64
#  5   fare         891 non-null    float64
#  6   embarked     889 non-null    object
#  7   class        891 non-null    category
#  8   who          891 non-null    object
#  9   adult_male   891 non-null    bool
#  10  deck         203 non-null    category
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(3), object(5)
# memory usage: 80.5+ KB

# %%
data.drop(['deck','who'],axis=1,inplace = True)
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class',
#        'adult_male', 'embark_town', 'alive', 'alone'],
#       dtype='object')

# %%
#to get round off values
avg_age = round(data['age'].mean())
print(avg_age)
# Out:
# 30

# %%
avg_age = data['age'].mean() #to get exact value
print(avg_age)
# Out:
# 29.713352080989875

# %%
print('Average age',round(data['age'].mean(),2))
# Out:
# Average age 29.7

# %%
data.isnull().sum() #to find null values in the columns
# Out:
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
data['age'].fillna(avg_age,inplace=True) # replace null values by average values
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5704\3803186038.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['age'].fillna(avg_age,inplace=True) #replace null values by average values

# %%
data
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked   class  \
# survived
# 0              3    male  22.0      1      0   7.2500        S   Third
# 1              1  female  38.0      1      0  71.2833        C   First
# 1              3  female  26.0      0      0   7.9250        S   Third
# 1              1  female  35.0      1      0  53.1000        S   First
# 0              3    male  35.0      0      0   8.0500        S   Third
# ...          ...     ...   ...    ...    ...      ...      ...     ...
# 0              2    male  27.0      0      0  13.0000        S  Second
# 1              1  female  19.0      0      0  30.0000        S   First
# 0              3  female  30.0      1      2  23.4500        S   Third
# 1              1    male  26.0      0      0  30.0000        C   First
# 0              3    male  32.0      0      0   7.7500        Q   Third
#
#           adult_male  embark_town alive  alone
# survived
# ...

# %%
#to drop all null values in the embarked column

data.dropna(subset=['embarked'], inplace = True) # subset is used to specify the column to drop the null values from

# %%
data
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked   class  \
# survived
# 0              3    male  22.0      1      0   7.2500        S   Third
# 1              1  female  38.0      1      0  71.2833        C   First
# 1              3  female  26.0      0      0   7.9250        S   Third
# 1              1  female  35.0      1      0  53.1000        S   First
# 0              3    male  35.0      0      0   8.0500        S   Third
# ...          ...     ...   ...    ...    ...      ...      ...     ...
# 0              2    male  27.0      0      0  13.0000        S  Second
# 1              1  female  19.0      0      0  30.0000        S   First
# 0              3  female  30.0      1      2  23.4500        S   Third
# 1              1    male  26.0      0      0  30.0000        C   First
# 0              3    male  32.0      0      0   7.7500        Q   Third
#
#           adult_male  embark_town alive  alone
# survived
# ...

# %%
#value count mathod(find categorical values in the data in particular column)
data['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
#to find maximum count of value in the particular column

data['embark_town'].value_counts().idxmax()
# Out:
# 'Southampton'

# %%
#to find minimum count of value in the particular column

data['embark_town'].value_counts().idxmin()
# Out:
# 'Queenstown'
